# %% [markdown]
# <a href="https://colab.research.google.com/github/zaladmander/Analyzing-Attributes-of-AI-Generated-vs.-Human-Written-Text/blob/main/loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

csv_url = 'https://raw.githubusercontent.com/zaladmander/Analyzing-Attributes-of-AI-Generated-vs.-Human-Written-Text/refs/heads/main/ai_vs_human_dataset_medium.csv'
df = pd.read_csv(csv_url)

# %%
print(df.columns)
# Out:
# Index(['id', 'label', 'topic', 'text', 'length_chars', 'length_words',
#        'quality_score', 'sentiment', 'source_detail', 'timestamp',
#        'plagiarism_score', 'notes'],
#       dtype='str')

# %%
# print("\nFirst 5 records:\n", df.head(5))

# print("\nData description: \n", df.describe())

#df = df.drop(columns=["notes", "timestamp"])

#print("\nDataset shape:", df.shape)
print("\ndatatypes: \n", df.dtypes)
print("\n")

missing = df.isnull().sum()
print("\nMissing values per column:\n", missing)
# Out:
# datatypes:
#  id                    int64
# label                   str
# topic                   str
# text                    str
# length_chars          int64
# length_words          int64
# quality_score       float64
# sentiment           float64
# source_detail           str
# plagiarism_score    float64
# dtype: object
#
#
#
# Missing values per column:
#  id                  0
# label               0
# topic               0
# text                0
# length_chars        0
# length_words        0
# quality_score       0
# sentiment           0
# source_detail       0
# plagiarism_score    0
# dtype: int64

# %%
import numpy as np
# sources = pd.Series(df.groupby("source_detail")["source_detail"])
# sources = np.array(sources)
sources = df['source_detail'].dropna().unique()
print(sources)
# Out:
# <StringArray>
# [    'author_50',    'gpt-5-base',     'author_33',      'claude-2',
#      'author_87',   'gpt-4o-mini', 'llama-3-small',     'author_73',
#      'author_85',     'author_49',     'author_61',     'author_37',
#      'author_72',     'author_91',     'author_59',     'author_74',
#      'author_10',     'bloomz-7b',     'author_90',     'author_21',
#       'author_7',     'author_34',     'author_23',     'author_80',
#      'author_88',     'author_22',     'author_83',     'author_54',
#     'author_100',     'author_26',     'author_93',     'author_97',
#      'author_52',     'author_79',     'author_15',     'author_99',
#      'author_56',     'author_28',     'author_11',      'author_9',
#      'author_32',     'author_69',     'author_63',     'author_27',
#      'author_40',     'author_62',     'author_44',     'author_92',
#      'author_67',     'author_29',     'author_20',     'author_16',
#      'author_30',      'author_1',     'author_25',     'author_77',
#      'author_39',      'author_8',     'author_31',     'author_71',
#      'author_17',     'author_48',     'author_51',     'author_82',
#      'author_53',     'author_18',     'author_47',     'author_65',
#      'author_19',     'author_94',     'author_38',     'author_13',
#      'author_35',      'author_5',      'author_2',     'author_75',
#      'author_95',      'author_6',     'author_57',     'author_58',
#      'author_86',     'author_55',     'author_41',     'author_12',
#      'author_98',      'author_3',     'author_70',     'author_76',
#      'author_45',     'author_43',     'author_42',     'author_14',
#      'author_81',     'author_66',     'author_60']
# Length: 95, dtype: str
# Index(['id', 'label', 'topic', 'text', 'length_chars', 'length_words',
#        'quality_score', 'sentiment', 'source_detail', 'timestamp',
#        'plagiarism_score', 'notes'],
#       dtype='str')
